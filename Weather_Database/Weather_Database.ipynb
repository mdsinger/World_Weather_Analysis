# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
city_data = []
lats = []
lngs = []


lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = []

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for lat_lng in lat_lngs:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import api_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13348\4250291943.py in <module>
#       9
#      10 # Import the OpenWeatherMap's API key
# ---> 11 from config import api_key
#
# ImportError: cannot import name 'api_key' from 'config' (C:\Users\MDLEW\anaconda3\envs\PythonData\lib\site-packages\config\__init__.py)

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=96d2d88f2aab278f3d7d5dad58a269a3"

# %%
city_url = url + "&q=" + cities[4].replace(" ","+")
city_weather = requests.get(city_url).json()
city_lng = city_weather["coord"]["lon"]
city_lng
# Out:
# -77.5714

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Country": city_country})
    
    # If an error is experienced, skip the city
    except: 
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | berdigestyakh
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | ponta delgada
# Processing Record 5 of Set 1 | lewistown
# Processing Record 6 of Set 1 | grimmen
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | port-cartier
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | trowbridge
# Processing Record 16 of Set 1 | nelson bay
# Processing Record 17 of Set 1 | arequipa
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | mount isa
# Processing Record 22 of Set 1 | bulgan
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 1 | itaberaba
# Processing Record 27 of Set 1 | honiara
# Processing Record 28 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | henties bay
# Processing Record 31 of Set 1 | berlevag
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | gizo
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | ixtapa
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | klaksvik
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | oussouye
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | marawi
# Processing Record 47 of Set 1 | begunitsy
# Processing Record 48 of Set 1 | locri
# Processing Record 49 of Set 1 | clyde river
# Processing Record 50 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 2 | zhigalovo
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | hamilton
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | ust-barguzin
# Processing Record 8 of Set 2 | hailakandi
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | bilma
# Processing Record 13 of Set 2 | choucheng
# City not found. Skipping...
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | tianpeng
# Processing Record 18 of Set 2 | morehead
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | salalah
# Processing Record 21 of Set 2 | yenagoa
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | staryy nadym
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | te anau
# Processing Record 28 of Set 2 | zhangjiakou
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | manokwari
# Processing Record 31 of Set 2 | pacific grove
# Processing Record 32 of Set 2 | saint-pierre
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | legnica
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | san juan
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | mathbaria
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | prince rupert
# Processing Record 45 of Set 2 | ust-tarka
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | alice springs
# Processing Record 50 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 3 | umm kaddadah
# Processing Record 2 of Set 3 | bartica
# Processing Record 3 of Set 3 | baykit
# Processing Record 4 of Set 3 | broome
# Processing Record 5 of Set 3 | merauke
# Processing Record 6 of Set 3 | kaka
# Processing Record 7 of Set 3 | laguna
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | iwaki
# Processing Record 12 of Set 3 | hofn
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | waipawa
# Processing Record 15 of Set 3 | mahanoro
# Processing Record 16 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 3 | zeya
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | avera
# Processing Record 20 of Set 3 | palmer
# Processing Record 21 of Set 3 | wangaratta
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | eyl
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | ilebo
# Processing Record 28 of Set 3 | chipata
# Processing Record 29 of Set 3 | altay
# Processing Record 30 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | tommot
# Processing Record 34 of Set 3 | mulege
# Processing Record 35 of Set 3 | westport
# Processing Record 36 of Set 3 | fuzhou
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | cayenne
# Processing Record 39 of Set 3 | manzil salim
# Processing Record 40 of Set 3 | yongchang
# Processing Record 41 of Set 3 | pozzallo
# Processing Record 42 of Set 3 | kahului
# Processing Record 43 of Set 3 | kalmunai
# Processing Record 44 of Set 3 | banyo
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | hualmay
# Processing Record 49 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | vila velha
# Processing Record 2 of Set 4 | trincomalee
# Processing Record 3 of Set 4 | lake havasu city
# Processing Record 4 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | muisne
# Processing Record 7 of Set 4 | mbanza-ngungu
# Processing Record 8 of Set 4 | popondetta
# Processing Record 9 of Set 4 | solnechnyy
# Processing Record 10 of Set 4 | chifeng
# Processing Record 11 of Set 4 | hemsedal
# Processing Record 12 of Set 4 | biak
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | panzhihua
# Processing Record 15 of Set 4 | manutuke
# Processing Record 16 of Set 4 | norrtalje
# Processing Record 17 of Set 4 | kharp
# Processing Record 18 of Set 4 | bluff
# Processing Record 19 of Set 4 | srednekolymsk
# Processing Record 20 of Set 4 | teguise
# Processing Record 21 of Set 4 | bengkulu
# Processing Record 22 of Set 4 | xiongzhou
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | port arthur
# Processing Record 25 of Set 4 | seddon
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | comodoro rivadavia
# Processing Record 32 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | luanda
# Processing Record 37 of Set 4 | talaya
# Processing Record 38 of Set 4 | voyinka
# Processing Record 39 of Set 4 | neryungri
# Processing Record 40 of Set 4 | rovaniemi
# Processing Record 41 of Set 4 | lovington
# Processing Record 42 of Set 4 | nara
# Processing Record 43 of Set 4 | codrington
# Processing Record 44 of Set 4 | laurel
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | rosetta
# Processing Record 47 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 4 | torrington
# Processing Record 49 of Set 4 | lokosovo
# Processing Record 50 of Set 4 | russell
# Processing Record 1 of Set 5 | praia
# Processing Record 2 of Set 5 | paamiut
# Processing Record 3 of Set 5 | sistranda
# Processing Record 4 of Set 5 | yar-sale
# Processing Record 5 of Set 5 | jobner
# Processing Record 6 of Set 5 | buarcos
# Processing Record 7 of Set 5 | haicheng
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | cherdyn
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | vanimo
# Processing Record 13 of Set 5 | high prairie
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 5 | puerto del rosario
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | port elizabeth
# Processing Record 20 of Set 5 | kargasok
# Processing Record 21 of Set 5 | praia da vitoria
# Processing Record 22 of Set 5 | wajir
# Processing Record 23 of Set 5 | mandalgovi
# Processing Record 24 of Set 5 | sola
# Processing Record 25 of Set 5 | pekalongan
# Processing Record 26 of Set 5 | saiha
# Processing Record 27 of Set 5 | oliveira dos brejinhos
# Processing Record 28 of Set 5 | salinopolis
# Processing Record 29 of Set 5 | kasongo-lunda
# Processing Record 30 of Set 5 | maltahohe
# Processing Record 31 of Set 5 | chopinzinho
# Processing Record 32 of Set 5 | manoel urbano
# Processing Record 33 of Set 5 | dakar
# Processing Record 34 of Set 5 | kupang
# Processing Record 35 of Set 5 | ercis
# Processing Record 36 of Set 5 | xining
# Processing Record 37 of Set 5 | jodhpur
# Processing Record 38 of Set 5 | acajutla
# Processing Record 39 of Set 5 | santa rosa
# Processing Record 40 of Set 5 | margate
# Processing Record 41 of Set 5 | trairi
# Processing Record 42 of Set 5 | nyurba
# Processing Record 43 of Set 5 | nuuk
# Processing Record 44 of Set 5 | angra
# City not found. Skipping...
# Processing Record 45 of Set 5 | qasigiannguit
# Processing Record 46 of Set 5 | general pico
# Processing Record 47 of Set 5 | mpanda
# Processing Record 48 of Set 5 | tazovskiy
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 1 of Set 6 | inhambane
# Processing Record 2 of Set 6 | sao joao da barra
# Processing Record 3 of Set 6 | pevek
# Processing Record 4 of Set 6 | mapimi
# Processing Record 5 of Set 6 | kajaani
# Processing Record 6 of Set 6 | narsaq
# Processing Record 7 of Set 6 | dikson
# Processing Record 8 of Set 6 | nouadhibou
# Processing Record 9 of Set 6 | taoudenni
# Processing Record 10 of Set 6 | tarauaca
# Processing Record 11 of Set 6 | faanui
# Processing Record 12 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 13 of Set 6 | encheng
# Processing Record 14 of Set 6 | mackay
# Processing Record 15 of Set 6 | fontenay-le-comte
# Processing Record 16 of Set 6 | pasighat
# Processing Record 17 of Set 6 | imbituba
# Processing Record 18 of Set 6 | pipri
# Processing Record 19 of Set 6 | kazanskaya
# Processing Record 20 of Set 6 | koumra
# Processing Record 21 of Set 6 | mislinja
# Processing Record 22 of Set 6 | tabou
# Processing Record 23 of Set 6 | taltal
# Processing Record 24 of Set 6 | pemba
# Processing Record 25 of Set 6 | hobart
# Processing Record 26 of Set 6 | vytegra
# Processing Record 27 of Set 6 | pilar
# Processing Record 28 of Set 6 | komsomolskiy
# Processing Record 29 of Set 6 | surskoye
# Processing Record 30 of Set 6 | san quintin
# Processing Record 31 of Set 6 | the valley
# Processing Record 32 of Set 6 | sao filipe
# Processing Record 33 of Set 6 | sitka
# Processing Record 34 of Set 6 | zhezkazgan
# Processing Record 35 of Set 6 | blacksburg
# Processing Record 36 of Set 6 | crossford
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | haverfordwest
# Processing Record 39 of Set 6 | havre-saint-pierre
# Processing Record 40 of Set 6 | talara
# Processing Record 41 of Set 6 | fairbanks
# Processing Record 42 of Set 6 | jalu
# Processing Record 43 of Set 6 | acapulco
# Processing Record 44 of Set 6 | lucapa
# Processing Record 45 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 46 of Set 6 | dingle
# Processing Record 47 of Set 6 | rawson
# Processing Record 48 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 49 of Set 6 | linjiang
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | buchanan
# Processing Record 2 of Set 7 | tiksi
# Processing Record 3 of Set 7 | ascension
# Processing Record 4 of Set 7 | nipawin
# Processing Record 5 of Set 7 | wanning
# Processing Record 6 of Set 7 | goundi
# Processing Record 7 of Set 7 | quatre cocos
# Processing Record 8 of Set 7 | maniitsoq
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | itaituba
# Processing Record 11 of Set 7 | idaho falls
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | tocopilla
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | igbo ora
# Processing Record 16 of Set 7 | magadan
# Processing Record 17 of Set 7 | wamba
# Processing Record 18 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 7 | port augusta
# Processing Record 20 of Set 7 | yarmouth
# Processing Record 21 of Set 7 | port-gentil
# Processing Record 22 of Set 7 | asosa
# Processing Record 23 of Set 7 | ovre ardal
# Processing Record 24 of Set 7 | gornopravdinsk
# Processing Record 25 of Set 7 | upernavik
# Processing Record 26 of Set 7 | moissala
# Processing Record 27 of Set 7 | mayumba
# Processing Record 28 of Set 7 | anloga
# Processing Record 29 of Set 7 | kanigoro
# Processing Record 30 of Set 7 | sao gabriel da cachoeira
# Processing Record 31 of Set 7 | ancud
# Processing Record 32 of Set 7 | palafrugell
# Processing Record 33 of Set 7 | san policarpo
# Processing Record 34 of Set 7 | busca
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | son la
# Processing Record 37 of Set 7 | puerto carreno
# Processing Record 38 of Set 7 | sandpoint
# Processing Record 39 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 7 | sandakan
# Processing Record 41 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 7 | tsabong
# Processing Record 43 of Set 7 | skalat
# Processing Record 44 of Set 7 | pangkalanbuun
# Processing Record 45 of Set 7 | elizabeth city
# Processing Record 46 of Set 7 | whitehorse
# Processing Record 47 of Set 7 | saldanha
# Processing Record 48 of Set 7 | maan
# Processing Record 49 of Set 7 | krasnotorka
# Processing Record 50 of Set 7 | necochea
# Processing Record 1 of Set 8 | fontem
# Processing Record 2 of Set 8 | sabha
# Processing Record 3 of Set 8 | galway
# Processing Record 4 of Set 8 | zhukovka
# Processing Record 5 of Set 8 | bathsheba
# Processing Record 6 of Set 8 | yumen
# Processing Record 7 of Set 8 | matamoros
# Processing Record 8 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 8 | ous
# Processing Record 10 of Set 8 | latung
# Processing Record 11 of Set 8 | christchurch
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | portland
# Processing Record 14 of Set 8 | maymanak
# City not found. Skipping...
# Processing Record 15 of Set 8 | scarborough
# Processing Record 16 of Set 8 | roma
# Processing Record 17 of Set 8 | nanortalik
# Processing Record 18 of Set 8 | bagdarin
# Processing Record 19 of Set 8 | aksarka
# Processing Record 20 of Set 8 | ambulu
# Processing Record 21 of Set 8 | kruisfontein
# Processing Record 22 of Set 8 | kununurra
# Processing Record 23 of Set 8 | katsuura
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | lata
# Processing Record 26 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | pangody
# Processing Record 29 of Set 8 | takoradi
# Processing Record 30 of Set 8 | korla
# Processing Record 31 of Set 8 | cheremnoye
# Processing Record 32 of Set 8 | evensk
# Processing Record 33 of Set 8 | san jeronimo
# Processing Record 34 of Set 8 | sibenik
# Processing Record 35 of Set 8 | huarmey
# Processing Record 36 of Set 8 | fare
# Processing Record 37 of Set 8 | raton
# Processing Record 38 of Set 8 | mackenzie
# Processing Record 39 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 8 | leningradskiy
# Processing Record 41 of Set 8 | seoul
# Processing Record 42 of Set 8 | byumba
# Processing Record 43 of Set 8 | ostrovnoy
# Processing Record 44 of Set 8 | rio gallegos
# Processing Record 45 of Set 8 | tigil
# Processing Record 46 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 8 | nemuro
# Processing Record 48 of Set 8 | port lincoln
# Processing Record 49 of Set 8 | pierre
# Processing Record 50 of Set 8 | staunton
# Processing Record 1 of Set 9 | ibra
# Processing Record 2 of Set 9 | santander
# Processing Record 3 of Set 9 | otuzco
# Processing Record 4 of Set 9 | ulladulla
# Processing Record 5 of Set 9 | nantucket
# Processing Record 6 of Set 9 | shaping
# Processing Record 7 of Set 9 | tucupita
# Processing Record 8 of Set 9 | marystown
# Processing Record 9 of Set 9 | matara
# Processing Record 10 of Set 9 | vao
# Processing Record 11 of Set 9 | vagur
# Processing Record 12 of Set 9 | cankuzo
# Processing Record 13 of Set 9 | carauari
# Processing Record 14 of Set 9 | muroto
# Processing Record 15 of Set 9 | talcahuano
# Processing Record 16 of Set 9 | makakilo city
# Processing Record 17 of Set 9 | haines junction
# Processing Record 18 of Set 9 | providencia
# Processing Record 19 of Set 9 | tezu
# Processing Record 20 of Set 9 | valparaiso
# Processing Record 21 of Set 9 | dauphin
# Processing Record 22 of Set 9 | cherskiy
# Processing Record 23 of Set 9 | brewster
# Processing Record 24 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | manono
# Processing Record 26 of Set 9 | jishou
# Processing Record 27 of Set 9 | gobabis
# Processing Record 28 of Set 9 | ebebiyin
# Processing Record 29 of Set 9 | odweyne
# Processing Record 30 of Set 9 | zamboanguita
# Processing Record 31 of Set 9 | turukhansk
# Processing Record 32 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 9 | asyut
# Processing Record 34 of Set 9 | kungalv
# Processing Record 35 of Set 9 | port keats
# Processing Record 36 of Set 9 | neuquen
# Processing Record 37 of Set 9 | yangambi
# Processing Record 38 of Set 9 | san cristobal
# Processing Record 39 of Set 9 | eureka
# Processing Record 40 of Set 9 | katobu
# Processing Record 41 of Set 9 | waddan
# Processing Record 42 of Set 9 | svetlogorsk
# Processing Record 43 of Set 9 | rudbar
# Processing Record 44 of Set 9 | zatoka
# Processing Record 45 of Set 9 | santa isabel
# Processing Record 46 of Set 9 | khasan
# Processing Record 47 of Set 9 | alyangula
# Processing Record 48 of Set 9 | marzuq
# Processing Record 49 of Set 9 | sisimiut
# Processing Record 50 of Set 9 | grand gaube
# Processing Record 1 of Set 10 | borova
# Processing Record 2 of Set 10 | pandan
# Processing Record 3 of Set 10 | axim
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | pak phanang
# Processing Record 6 of Set 10 | atar
# Processing Record 7 of Set 10 | cervo
# Processing Record 8 of Set 10 | burica
# City not found. Skipping...
# Processing Record 9 of Set 10 | soke
# Processing Record 10 of Set 10 | olhao
# Processing Record 11 of Set 10 | arkhangelsk
# Processing Record 12 of Set 10 | ayan
# Processing Record 13 of Set 10 | egvekinot
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | ambanja
# Processing Record 16 of Set 10 | novosheshminsk
# Processing Record 17 of Set 10 | wainwright
# Processing Record 18 of Set 10 | vernon
# Processing Record 19 of Set 10 | thinadhoo
# Processing Record 20 of Set 10 | puerto colombia
# Processing Record 21 of Set 10 | broken hill
# Processing Record 22 of Set 10 | qinhuangdao
# Processing Record 23 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 10 | fukuma
# Processing Record 25 of Set 10 | norman wells
# Processing Record 26 of Set 10 | karratha
# Processing Record 27 of Set 10 | severodvinsk
# Processing Record 28 of Set 10 | boden
# Processing Record 29 of Set 10 | havoysund
# Processing Record 30 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 10 | tillabery
# City not found. Skipping...
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | bhag
# Processing Record 34 of Set 10 | cabedelo
# Processing Record 35 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 36 of Set 10 | auly
# Processing Record 37 of Set 10 | ambilobe
# Processing Record 38 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 10 | amapa
# Processing Record 40 of Set 10 | mafinga
# Processing Record 41 of Set 10 | yeppoon
# Processing Record 42 of Set 10 | arman
# Processing Record 43 of Set 10 | kozulka
# Processing Record 44 of Set 10 | tondano
# Processing Record 45 of Set 10 | donji vakuf
# Processing Record 46 of Set 10 | nandu
# Processing Record 47 of Set 10 | batagay
# Processing Record 48 of Set 10 | koungou
# Processing Record 49 of Set 10 | palasa
# Processing Record 50 of Set 10 | coquimbo
# Processing Record 1 of Set 11 | zaragoza
# Processing Record 2 of Set 11 | hyeres
# Processing Record 3 of Set 11 | kaeo
# Processing Record 4 of Set 11 | tura
# Processing Record 5 of Set 11 | namibe
# Processing Record 6 of Set 11 | tilichiki
# Processing Record 7 of Set 11 | gimli
# Processing Record 8 of Set 11 | damoh
# Processing Record 9 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | hatillo
# Processing Record 11 of Set 11 | catuday
# Processing Record 12 of Set 11 | sibolga
# Processing Record 13 of Set 11 | paranavai
# Processing Record 14 of Set 11 | mezen
# Processing Record 15 of Set 11 | ouadda
# Processing Record 16 of Set 11 | chapais
# Processing Record 17 of Set 11 | sorland
# Processing Record 18 of Set 11 | casper
# Processing Record 19 of Set 11 | mufumbwe
# Processing Record 20 of Set 11 | san francisco
# Processing Record 21 of Set 11 | beringovskiy
# Processing Record 22 of Set 11 | lagoa
# Processing Record 23 of Set 11 | rincon
# Processing Record 24 of Set 11 | mount gambier
# Processing Record 25 of Set 11 | abonnema
# Processing Record 26 of Set 11 | orsta
# Processing Record 27 of Set 11 | sestri levante
# Processing Record 28 of Set 11 | yulara
# Processing Record 29 of Set 11 | rafai
# Processing Record 30 of Set 11 | saint-francois
# Processing Record 31 of Set 11 | acarau
# Processing Record 32 of Set 11 | nanakuli
# Processing Record 33 of Set 11 | byron bay
# Processing Record 34 of Set 11 | tres arroyos
# Processing Record 35 of Set 11 | bilibino
# Processing Record 36 of Set 11 | caranavi
# Processing Record 37 of Set 11 | praya
# Processing Record 38 of Set 11 | mayo
# Processing Record 39 of Set 11 | lasa
# Processing Record 40 of Set 11 | cocorit
# Processing Record 41 of Set 11 | escarcega
# Processing Record 42 of Set 11 | kysyl-syr
# Processing Record 43 of Set 11 | isangel
# Processing Record 44 of Set 11 | natal
# Processing Record 45 of Set 11 | tecoanapa
# Processing Record 46 of Set 11 | cockburn town
# Processing Record 47 of Set 11 | la ronge
# Processing Record 48 of Set 11 | osorno
# Processing Record 49 of Set 11 | qandala
# Processing Record 50 of Set 11 | gamba
# Processing Record 1 of Set 12 | murmashi
# Processing Record 2 of Set 12 | atikokan
# Processing Record 3 of Set 12 | port hardy
# Processing Record 4 of Set 12 | xinqing
# Processing Record 5 of Set 12 | maua
# Processing Record 6 of Set 12 | vila
# Processing Record 7 of Set 12 | tres picos
# Processing Record 8 of Set 12 | anuradhapura
# Processing Record 9 of Set 12 | sibut
# Processing Record 10 of Set 12 | saint-augustin
# Processing Record 11 of Set 12 | hirara
# Processing Record 12 of Set 12 | lekoni
# Processing Record 13 of Set 12 | yurty
# Processing Record 14 of Set 12 | tongliao
# Processing Record 15 of Set 12 | charagua
# Processing Record 16 of Set 12 | pervomayskoye
# Processing Record 17 of Set 12 | sinnamary
# Processing Record 18 of Set 12 | datong
# Processing Record 19 of Set 12 | tenenkou
# Processing Record 20 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 12 | jaru
# Processing Record 22 of Set 12 | jacareacanga
# Processing Record 23 of Set 12 | mukhen
# Processing Record 24 of Set 12 | vilcun
# Processing Record 25 of Set 12 | mehamn
# Processing Record 26 of Set 12 | dolores
# Processing Record 27 of Set 12 | kibondo
# Processing Record 28 of Set 12 | rexburg
# Processing Record 29 of Set 12 | manta
# Processing Record 30 of Set 12 | halifax
# Processing Record 31 of Set 12 | uruguaiana
# Processing Record 32 of Set 12 | mabaruma
# Processing Record 33 of Set 12 | constitucion
# Processing Record 34 of Set 12 | beyneu
# Processing Record 35 of Set 12 | grindavik
# Processing Record 36 of Set 12 | chirongui
# Processing Record 37 of Set 12 | mount pleasant
# Processing Record 38 of Set 12 | aksu
# Processing Record 39 of Set 12 | marabba
# Processing Record 40 of Set 12 | stavern
# Processing Record 41 of Set 12 | gorin
# Processing Record 42 of Set 12 | dongying
# Processing Record 43 of Set 12 | tuatapere
# Processing Record 44 of Set 12 | caravelas
# Processing Record 45 of Set 12 | haftoni
# Processing Record 46 of Set 12 | bowen
# Processing Record 47 of Set 12 | encantado
# Processing Record 48 of Set 12 | eregli
# Processing Record 49 of Set 12 | half moon bay
# Processing Record 50 of Set 12 | tiarei
# Processing Record 1 of Set 13 | belaya gora
# Processing Record 2 of Set 13 | puerto suarez
# Processing Record 3 of Set 13 | pokhara
# Processing Record 4 of Set 13 | iwade
# Processing Record 5 of Set 13 | dafeng
# Processing Record 6 of Set 13 | kieta
# Processing Record 7 of Set 13 | flagstaff
# Processing Record 8 of Set 13 | northam
# Processing Record 9 of Set 13 | okha
# Processing Record 10 of Set 13 | seminole
# Processing Record 11 of Set 13 | tall kayf
# Processing Record 12 of Set 13 | biskamzha
# Processing Record 13 of Set 13 | jiaonan
# Processing Record 14 of Set 13 | cap-aux-meules
# Processing Record 15 of Set 13 | bonoua
# Processing Record 16 of Set 13 | soyo
# Processing Record 17 of Set 13 | ipixuna
# Processing Record 18 of Set 13 | kilifarevo
# Processing Record 19 of Set 13 | strazske
# Processing Record 20 of Set 13 | shemonaikha
# Processing Record 21 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 22 of Set 13 | atherton
# Processing Record 23 of Set 13 | ilo
# Processing Record 24 of Set 13 | alpena
# Processing Record 25 of Set 13 | tiznit
# Processing Record 26 of Set 13 | aykhal
# Processing Record 27 of Set 13 | makamba
# Processing Record 28 of Set 13 | sekoma
# Processing Record 29 of Set 13 | sztum
# Processing Record 30 of Set 13 | beloha
# Processing Record 31 of Set 13 | vidim
# Processing Record 32 of Set 13 | corbu
# Processing Record 33 of Set 13 | rodrigues alves
# Processing Record 34 of Set 13 | ballitoville
# Processing Record 35 of Set 13 | marsh harbour
# Processing Record 36 of Set 13 | san rafael del sur
# Processing Record 37 of Set 13 | japura
# Processing Record 38 of Set 13 | changji
# Processing Record 39 of Set 13 | garowe
# Processing Record 40 of Set 13 | gloversville
# Processing Record 41 of Set 13 | saint-louis
# Processing Record 42 of Set 13 | parnarama
# Processing Record 43 of Set 13 | yate
# Processing Record 44 of Set 13 | nhulunbuy
# Processing Record 45 of Set 13 | rurrenabaque
# Processing Record 46 of Set 13 | mirabad
# Processing Record 47 of Set 13 | coahuayana
# Processing Record 48 of Set 13 | podujevo
# Processing Record 49 of Set 13 | buritizeiro
# Processing Record 50 of Set 13 | verkhoyansk
# Processing Record 1 of Set 14 | goundam
# Processing Record 2 of Set 14 | champerico
# Processing Record 3 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 14 | tupik
# Processing Record 5 of Set 14 | ellisras
# Processing Record 6 of Set 14 | hovd
# Processing Record 7 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 14 | lander
# Processing Record 9 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 14 | sorgun
# Processing Record 11 of Set 14 | bonthe
# Processing Record 12 of Set 14 | leonidion
# City not found. Skipping...
# Processing Record 13 of Set 14 | nchelenge
# Processing Record 14 of Set 14 | wasilla
# Processing Record 15 of Set 14 | labuhan
# Processing Record 16 of Set 14 | great yarmouth
# Processing Record 17 of Set 14 | north bend
# Processing Record 18 of Set 14 | indianola
# Processing Record 19 of Set 14 | bayir
# Processing Record 20 of Set 14 | gorontalo
# Processing Record 21 of Set 14 | nicholasville
# Processing Record 22 of Set 14 | edd
# Processing Record 23 of Set 14 | worthington
# Processing Record 24 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 14 | seryshevo
# Processing Record 26 of Set 14 | barra do garcas
# Processing Record 27 of Set 14 | adre
# Processing Record 28 of Set 14 | briancon
# Processing Record 29 of Set 14 | rio grande
# Processing Record 30 of Set 14 | hambantota
# Processing Record 31 of Set 14 | chicama
# Processing Record 32 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 33 of Set 14 | pauini
# Processing Record 34 of Set 14 | delta del tigre
# Processing Record 35 of Set 14 | maceio
# Processing Record 36 of Set 14 | novato
# Processing Record 37 of Set 14 | grootegast
# Processing Record 38 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 14 | gwanda
# Processing Record 40 of Set 14 | marrakesh
# Processing Record 41 of Set 14 | farnworth
# Processing Record 42 of Set 14 | bratsk
# Processing Record 43 of Set 14 | rafaela
# Processing Record 44 of Set 14 | sinnar
# Processing Record 45 of Set 14 | reims
# Processing Record 46 of Set 14 | alofi
# Processing Record 47 of Set 14 | yerbogachen
# Processing Record 48 of Set 14 | itupiranga
# Processing Record 49 of Set 14 | san jose
# Processing Record 50 of Set 14 | amahai
# Processing Record 1 of Set 15 | penukonda
# Processing Record 2 of Set 15 | fereydunshahr
# Processing Record 3 of Set 15 | harper
# Processing Record 4 of Set 15 | roald
# Processing Record 5 of Set 15 | saraland
# Processing Record 6 of Set 15 | mahbubabad
# Processing Record 7 of Set 15 | martina franca
# Processing Record 8 of Set 15 | ciudad real
# Processing Record 9 of Set 15 | tortoli
# Processing Record 10 of Set 15 | husavik
# Processing Record 11 of Set 15 | victor harbor
# Processing Record 12 of Set 15 | surt
# Processing Record 13 of Set 15 | arkansas city
# Processing Record 14 of Set 15 | poum
# Processing Record 15 of Set 15 | sept-iles
# Processing Record 16 of Set 15 | noumea
# Processing Record 17 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 15 | coihaique
# Processing Record 19 of Set 15 | manbij
# Processing Record 20 of Set 15 | aktash
# Processing Record 21 of Set 15 | hanzhong
# Processing Record 22 of Set 15 | aguimes
# Processing Record 23 of Set 15 | panama city
# Processing Record 24 of Set 15 | najran
# Processing Record 25 of Set 15 | dhidhdhoo
# Processing Record 26 of Set 15 | dwarka
# Processing Record 27 of Set 15 | am timan
# Processing Record 28 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 15 | thunder bay
# Processing Record 30 of Set 15 | sambava
# Processing Record 31 of Set 15 | senador guiomard
# Processing Record 32 of Set 15 | lahat
# Processing Record 33 of Set 15 | winkler
# Processing Record 34 of Set 15 | griffith
# Processing Record 35 of Set 15 | goderich
# Processing Record 36 of Set 15 | bhander
# Processing Record 37 of Set 15 | kingston
# Processing Record 38 of Set 15 | smalininkai
# Processing Record 39 of Set 15 | port macquarie
# Processing Record 40 of Set 15 | mahina
# Processing Record 41 of Set 15 | ust-tsilma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Berdigestyakh  62.0989  126.6992      6.19        98         100
# 1         Albany  42.6001  -73.9662     37.26        90         100
# 2       Cidreira -30.1811  -50.2056     77.63        80          99
# 3  Ponta Delgada  37.7333  -25.6667     59.72        63          20
# 4      Lewistown  40.5992  -77.5714     44.73        81         100
# 5        Grimmen  54.1121   13.0405     33.98        62          14
# 6   Punta Arenas -53.1500  -70.9167     44.71        70          75
# 7   Port-Cartier  50.0334  -66.8654     24.91        67          84
# 8           Chuy -33.6971  -53.4616     79.03        56          43
# 9         Lompoc  34.6391 -120.4579     54.52        72         100
#
#    Wind Speed Country
# 0        1.92      RU
# 1        3.60      US
# 2        4.05      BR
# 3       14.97      PT
# 4       13.80      US
# 5        7.38      DE
# 6       17.27      CL
# 7        5.32      CA
# 8       10.38      UY
# 9       10.36      US

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:

# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df [['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Berdigestyakh      RU  62.0989  126.6992      6.19        98         100
# 1         Albany      US  42.6001  -73.9662     37.26        90         100
# 2       Cidreira      BR -30.1811  -50.2056     77.63        80          99
# 3  Ponta Delgada      PT  37.7333  -25.6667     59.72        63          20
# 4      Lewistown      US  40.5992  -77.5714     44.73        81         100
# 5        Grimmen      DE  54.1121   13.0405     33.98        62          14
# 6   Punta Arenas      CL -53.1500  -70.9167     44.71        70          75
# 7   Port-Cartier      CA  50.0334  -66.8654     24.91        67          84
# 8           Chuy      UY -33.6971  -53.4616     79.03        56          43
# 9         Lompoc      US  34.6391 -120.4579     54.52        72         100
#
#    Wind Speed
# 0        1.92
# 1        3.60
# 2        4.05
# 3       14.97
# 4       13.80
# 5        7.38
# 6       17.27
# 7        5.32
# 8       10.38
# 9       10.36

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv('WeatherPy_Database.csv')
